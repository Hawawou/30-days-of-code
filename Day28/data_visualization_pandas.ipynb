# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading datasets
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Basic Plots

# %%
tips[['tip', 'total_bill']].plot()
# Out:
# <AxesSubplot:>

# %%
titanic['age'].hist()
# Out:
# <AxesSubplot:>

# %%
# to create beautiful visualizations
plt.style.use('ggplot')

# %% [markdown]
# ggplot is a visualization library in R

# %%
titanic['age'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn-talk')
titanic['age'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
titanic['age'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('grayscale')
titanic['age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Plot

# %%
plt.style.use('seaborn-dark')
top_20 = tips['total_bill'][0:20]

top_20.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# plot stacked bar plots

top_30_rows = tips[0:30]
top_30_rows.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `.barh()` to create horizontal bar charts

# %%
first_30_passengers = titanic[0:30]
first_30_passengers.plot(kind='barh', stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histogram

# %%
first_30_passengers.plot(kind='hist', stacked=True, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
first_30_passengers.plot(kind='hist', stacked=True, bins=20, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
tips['size'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Box Plots

# %%
top_30_rows.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
top_30_rows.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Area Plots

# %%
size_top_bill = tips[['size', 'tip', 'total_bill']]
size_top_bill.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
# only display top 30 rows

size_top_bill[0:30].plot(kind='area', stacked=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Kernel Density Estimation plots (KDE)

# %%
titanic['age'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Scatter Plots

# %%
tips.plot.scatter(x='tip', y='total_bill')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
tips.plot.scatter(x='tip', y='total_bill', color='Blue')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ### Hexagonal Plots

# %%
tips.plot.hexbin(x='tip', y='total_bill', gridsize=30)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ### Pie Plots

# %%
df = pd.DataFrame({'qty': [10, 20, 30],
                    'sales': [200, 700, 500]},
                    index=['Apple', 'Orange', 'Lemon'])
df.plot(kind='pie', y='qty')
# Out:
# <AxesSubplot:ylabel='qty'>

# %%
df.plot(kind='pie', subplots=True)
# Out:
# array([<AxesSubplot:ylabel='qty'>, <AxesSubplot:ylabel='sales'>],
#       dtype=object)
